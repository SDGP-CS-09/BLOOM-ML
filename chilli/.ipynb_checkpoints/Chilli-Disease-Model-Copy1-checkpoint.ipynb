# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE=256
BATCH_SIZE=32
CHANNELS=3
EPOCHS=20

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "train",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 490 files belonging to 5 classes.

# %%
# Get the number of classes
class_names = dataset.class_names
n_classes = len(class_names)  

print("Class Names:", class_names)
print("Number of Classes:", n_classes)
# Out:
# Class Names: ['healthy', 'leaf curl', 'leaf spot', 'whitefly', 'yellowish']
# Number of Classes: 5

# %%
len(dataset)
# Out:
# 16

# %%
for image_batch,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [3 0 1 0 4 1 2 0 4 2 4 4 1 2 4 2 0 2 1 4 1 4 4 2 4 4 0 1 4 3 0 1]

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
#*80% ==>training,
#0% ==>10% validation, 10% test

# %%
train_size=0.8
len(dataset)*train_size
# Out:
# 12.8

# %%
train_ds=dataset.take(54)
len(train_ds)
# Out:
# 16

# %%
test_ds=dataset.skip(54)
len(test_ds)
# Out:
# 0

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 1.6

# %%
val_ds=test_ds.take(6)
len(val_ds)
# Out:
# 0

# %%
test_ds=test_ds.skip(6)
len(test_ds)
# Out:
# 0

# %%
def get_dataset_partition_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size + val_size)

    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = get_dataset_partition_tf(dataset)

print("Training samples:", len(train_ds))
print("Validation samples:", len(val_ds))
print("Test samples:", len(test_ds))
# Out:
# Training samples: 12
# Validation samples: 1
# Test samples: 3

# %%
train_ds,val_ds,test_ds=get_dataset_partition_tf(dataset)

# %%
len(train_ds)
# Out:
# 12

# %%
len(val_ds)
# Out:
# 1

# %%
len(test_ds)
# Out:
# 3

# %%
# Optimize dataset loading
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0 / 255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %%
# Model architecture
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

model = models.Sequential([
    layers.Input(shape=input_shape), 
    resize_and_rescale,
    data_augmentation,

    # 1st Convolutional Block
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),

    # 2nd Convolutional Block
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # 3rd Convolutional Block
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # 4th Convolutional Block
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'), 
])
# Out:
# C:\Users\Sulochana\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.build(input_shape=(None, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │       3,211,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             325 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,600,069 (13.73 MB)
#  Trainable params: 3,600,069 (13.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 986ms/step - accuracy: 0.2137 - loss: 1.8737 - val_accuracy: 0.2812 - val_loss: 1.6002
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 981ms/step - accuracy: 0.2840 - loss: 1.5939 - val_accuracy: 0.3750 - val_loss: 1.4493
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 967ms/step - accuracy: 0.3118 - loss: 1.5500 - val_accuracy: 0.2188 - val_loss: 1.6132
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 963ms/step - accuracy: 0.1925 - loss: 1.5867 - val_accuracy: 0.2500 - val_loss: 1.5126
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 936ms/step - accuracy: 0.3482 - loss: 1.4834 - val_accuracy: 0.4062 - val_loss: 1.3322
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 963ms/step - accuracy: 0.3578 - loss: 1.4539 - val_accuracy: 0.4062 - val_loss: 1.3843
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4059 - loss: 1.3813 - val_accuracy: 0.5312 - val_loss: 1.3276
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 974ms/step - accuracy: 0.4020 - loss: 1.4053 - val_accuracy: 0.5000 - val_loss: 1.2943
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 952ms/step - accuracy: 0.4149 - loss: 1.3548 - val_accuracy: 0.5625 - val_loss: 1.2077
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 945ms/step - accuracy: 0.4896 - loss: 1.2435 - val_accuracy: 0.4062 - val_loss: 1.2712
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 936ms/step - accuracy: 0.4090 - loss: 1.3361 - val_accuracy: 0.5000 - val_loss: 1.2082
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 939ms/step - accuracy: 0.4896 - loss: 1.2177 - val_accuracy: 0.5312 - val_loss: 1.1491
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 957ms/step - accuracy: 0.4929 - loss: 1.1529 - val_accuracy: 0.5938 - val_loss: 1.1451
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 961ms/step - accuracy: 0.5102 - loss: 1.1473 - val_accuracy: 0.5312 - val_loss: 1.1614
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 956ms/step - accuracy: 0.5389 - loss: 1.0656 - val_accuracy: 0.5938 - val_loss: 1.1173
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 987ms/step - accuracy: 0.5257 - loss: 1.1392 - val_accuracy: 0.5625 - val_loss: 1.1339
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5406 - loss: 1.0895 - val_accuracy: 0.4688 - val_loss: 1.1344
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5504 - loss: 1.1342 - val_accuracy: 0.4688 - val_loss: 1.2115
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 999ms/step - accuracy: 0.5480 - loss: 1.0542 - val_accuracy: 0.4688 - val_loss: 1.2732
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 968ms/step - accuracy: 0.5740 - loss: 1.0881 - val_accuracy: 0.5312 - val_loss: 1.1687

# %%
scores = model.evaluate(test_ds)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 0.5273 - loss: 1.0319

# %%
scores
# Out:
# [1.0410386323928833, 0.5]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 20, 'steps': 12}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history.history['accuracy']
# Out:
# [0.2213541716337204,
#  0.2578125,
#  0.2786458432674408,
#  0.2057291716337204,
#  0.3333333432674408,
#  0.3802083432674408,
#  0.4036458432674408,
#  0.4348958432674408,
#  0.4661458432674408,
#  0.4609375,
#  0.4322916567325592,
#  0.4791666567325592,
#  0.453125,
#  0.5026041865348816,
#  0.5104166865348816,
#  0.5338541865348816,
#  0.5130208134651184,
#  0.5390625,
#  0.5234375,
#  0.5572916865348816]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize =(8,8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS),acc, label = 'Training Accuracy')
plt.plot(range(EPOCHS),val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label = 'Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:", class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: leaf spot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# predicted label: whitefly

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize = (15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class}\n Predicted: {predicted_class}.\n confidence: {confidence}%")


        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
import os

folder_path = "model"

if os.path.exists(folder_path) and os.path.isdir(folder_path):
    print(os.listdir(folder_path))
else:
    print(f"Error: Directory '{folder_path}' does not exist!")
# Out:
# ['v1.0.keras']

# %%
# Define the variable bellpepper_dep
chilli_dep = "v1.0"  # You can set this to the appropriate version string

# Now you can use it to save the model
model_version = chilli_dep
model.save(f"model/{model_version}.keras")  # Save the model with the version in the filename

# %%
model_path = "chilli_model.h5"

# Check if the model file exists
if os.path.exists(model_path):
    model = tf.keras.models.load_model(model_path)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    print("✅ Model loaded and compiled successfully!")
else:
    print(f"❌ Error: Model file '{model_path}' not found! Check the file path.")
# Out:
# ❌ Error: Model file 'chilli_model.h5' not found! Check the file path.
