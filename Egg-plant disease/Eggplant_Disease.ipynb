# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE=256
BATCH_SIZE=32
CHANNELS=3
EPOCHS=40

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "eggdata",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 9800 files belonging to 7 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Augmented Healthy Leaf',
#  'Augmented Insect Pest Disease',
#  'Augmented Leaf Spot Disease',
#  'Augmented Mosaic Virus Disease',
#  'Augmented Small Leaf Disease',
#  'Augmented White Mold Disease',
#  'Augmented Wilt Disease']

# %%
len(dataset)
# Out:
# 307

# %%
for image_batch,label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 256, 256, 3)
# [4 0 0 1 5 6 4 2 4 0 6 6 2 5 1 2 3 1 4 6 4 4 5 2 4 4 3 4 6 0 0 5]

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
#*80% ==>training,
#0% ==>10% validation, 10% test

# %%
train_size=0.8
len(dataset)*train_size
# Out:
# 245.60000000000002

# %%
train_ds=dataset.take(245)
len(train_ds)
# Out:
# 245

# %%
test_ds=dataset.skip(245)
len(test_ds)
# Out:
# 62

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 30.700000000000003

# %%
val_ds=test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds=test_ds.skip(6)
len(test_ds)
# Out:
# 56

# %%
def get_dataset_partition_tf(ds,train_split=0.8,val_split=0.1,test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size=len(ds)
    if shuffle:
        ds=ds.shuffle(shuffle_size,seed=12)

    train_size=int(train_split*ds_size)
    val_size=int(val_split*ds_size)

    train_ds=ds.take(train_size)

    val_ds=ds.skip(train_size).take(val_size)
    test_ds=ds.skip(train_size).skip(val_size)
    
    
    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds=get_dataset_partition_tf(dataset)

# %%
len(train_ds)
# Out:
# 245

# %%
len(val_ds)
# Out:
# 30

# %%
len(test_ds)
# Out:
# 32

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale =tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation=tf.keras.Sequential([
    layers.RandomFlip("horizontal_andvertical"),
    layers.RandomRotation(0.2),
])

# %%
input_shape=(BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes=7

model=models.Sequential([
    resize_and_rescale,
    data_augmentation,

    #1st Layer
    layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2,2)),

    # 2nd Convolutional Block
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # 3rd Convolutional Block
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # 4th Convolutional Block
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax'),
])

model.build(input_shape=input_shape)
# Out:
# C:\Users\Sulochana\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (32, 254, 254, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (32, 127, 127, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (32, 125, 125, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (32, 62, 62, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (32, 60, 60, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (32, 30, 30, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (32, 28, 28, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (32, 14, 14, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (32, 50176)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (32, 64)                    │       3,211,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (32, 7)                     │             455 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,600,199 (13.73 MB)
#  Trainable params: 3,600,199 (13.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
history = model.fit(
   train_ds,
   epochs=EPOCHS,
   verbose=1,
   validation_data=val_ds
)
# Out:
# Epoch 1/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 301s 1s/step - accuracy: 0.2253 - loss: 1.8047 - val_accuracy: 0.3792 - val_loss: 1.3998
# Epoch 2/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.4247 - loss: 1.3938 - val_accuracy: 0.3938 - val_loss: 1.4364
# Epoch 3/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 237s 968ms/step - accuracy: 0.4716 - loss: 1.2785 - val_accuracy: 0.5198 - val_loss: 1.2381
# Epoch 4/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 238s 970ms/step - accuracy: 0.5174 - loss: 1.1813 - val_accuracy: 0.5781 - val_loss: 1.0593
# Epoch 5/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 238s 971ms/step - accuracy: 0.5588 - loss: 1.0875 - val_accuracy: 0.5792 - val_loss: 1.0112
# Epoch 6/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 965ms/step - accuracy: 0.5950 - loss: 0.9867 - val_accuracy: 0.6146 - val_loss: 0.9761
# Epoch 7/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 238s 970ms/step - accuracy: 0.6318 - loss: 0.9103 - val_accuracy: 0.6656 - val_loss: 0.8885
# Epoch 8/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 237s 966ms/step - accuracy: 0.6481 - loss: 0.8750 - val_accuracy: 0.7333 - val_loss: 0.7271
# Epoch 9/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 237s 968ms/step - accuracy: 0.6950 - loss: 0.7628 - val_accuracy: 0.7177 - val_loss: 0.7288
# Epoch 10/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 964ms/step - accuracy: 0.7275 - loss: 0.6971 - val_accuracy: 0.7688 - val_loss: 0.5841
# Epoch 11/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 965ms/step - accuracy: 0.7590 - loss: 0.6287 - val_accuracy: 0.8104 - val_loss: 0.4844
# Epoch 12/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━
40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 235s 959ms/step - accuracy: 0.9416 - loss: 0.1571 - val_accuracy: 0.9344 - val_loss: 0.1801
# Epoch 34/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 237s 968ms/step - accuracy: 0.9482 - loss: 0.1519 - val_accuracy: 0.9281 - val_loss: 0.2063
# Epoch 35/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 963ms/step - accuracy: 0.9457 - loss: 0.1549 - val_accuracy: 0.9521 - val_loss: 0.1293
# Epoch 36/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 964ms/step - accuracy: 0.9545 - loss: 0.1335 - val_accuracy: 0.9250 - val_loss: 0.1877
# Epoch 37/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 962ms/step - accuracy: 0.9524 - loss: 0.1336 - val_accuracy: 0.9469 - val_loss: 0.1620
# Epoch 38/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 963ms/step - accuracy: 0.9652 - loss: 0.1024 - val_accuracy: 0.9167 - val_loss: 0.2498
# Epoch 39/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 963ms/step - accuracy: 0.9465 - loss: 0.1455 - val_accuracy: 0.9417 - val_loss: 0.1587
# Epoch 40/40
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 236s 964ms/step - accuracy: 0.9512 - loss: 0.1419 - val_accuracy: 0.9406 - val_loss: 0.1613

# %%
scores = model.evaluate(test_ds)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 270ms/step - accuracy: 0.9495 - loss: 0.1782

# %%
scores
# Out:
# [0.19628699123859406, 0.947265625]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 40, 'steps': 245}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
history.history['accuracy']
# Out:
# [0.2891581654548645,
#  0.43214285373687744,
#  0.48201531171798706,
#  0.5267857313156128,
#  0.5665816068649292,
#  0.6094387769699097,
#  0.6403061151504517,
#  0.667984664440155,
#  0.7014030814170837,
#  0.7339285612106323,
#  0.7627550959587097,
#  0.7855867147445679,
#  0.7993622422218323,
#  0.824617326259613,
#  0.8285714387893677,
#  0.8519132733345032,
#  0.8637754917144775,
#  0.8718112111091614,
#  0.8820152878761292,
#  0.8897958993911743,
#  0.8999999761581421,
#  0.9008928537368774,
#  0.9019132852554321,
#  0.9085459113121033,
#  0.9262754917144775,
#  0.9136479496955872,
#  0.9339285492897034,
#  0.9318877458572388,
#  0.9266581535339355,
#  0.9325255155563354,
#  0.9343112111091614,
#  0.9360969662666321,
#  0.9394132494926453,
#  0.9454081654548645,
#  0.9429847002029419,
#  0.9526785612106323,
#  0.9505102038383484,
#  0.9623724222183228,
#  0.9487245082855225,
#  0.952168345451355]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize =(8,8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS),acc, label = 'Training Accuracy')
plt.plot(range(EPOCHS),val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label = 'Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:", class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Augmented Healthy Leaf
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# predicted label: Augmented Healthy Leaf

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize = (15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")

        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]

        plt.title(f"Actual: {actual_class}\n Predicted: {predicted_class}.\n confidence: {confidence}%")


        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
import os
os.listdir("model")
# Out:
# ['v1.0.keras']

# %%
model.save("my_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
eggplant = "v1.0"  # You can set this to the appropriate version string

# Now you can use it to save the model
model_version = eggplant
model.save(f"model/{model_version}.keras")

# %%
# Load the model
model = tf.keras.models.load_model('bellpepper_model.h5')

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Load the model
# ----> 2 model = tf.keras.models.load_model('bellpepper_model.h5')
#       4 # Compile the model
#       5 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = 'bellpepper_model.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
